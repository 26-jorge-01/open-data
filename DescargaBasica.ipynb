# %%
import os
os.chdir('../..')  # Cambia al directorio raíz del proyecto

# %%
from Utils.OpenData.OpenDataConnection import OpenDataConnection, OpenDataBaseEnum

# %%
odc = OpenDataConnection(OpenDataBaseEnum.TVEC_ORDENES)
odc.load_open_data(limit=10)
odc.data.head(2)
# Out:
#     a_o identificador_de_la_orden rama_de_la_entidad orden_de_la_entidad  \
# 0  2021                     82703        No Definido         No Definido
# 1  2018                     30520        No Definido         No Definido
#
#   sector_de_la_entidad                                            entidad  \
# 0          No Definido  UNIDAD ADMINISTRATIVA ESPECIAL DE LA JUSTICIA ...
# 1          No Definido              EJERCITO NACIONAL - INTENDENCIA LOCAL
#
#                 solicitante                    fecha              fecha_vence  \
# 0        DIANA REYES PULIDO  2021-12-15T00:00:00.000  2021-12-31T00:00:00.000
# 1  ANDREA CAROLINA RESTREPO  2018-08-10T00:00:00.000  2018-12-31T00:00:00.000
#
#                        proveedor  ...  \
# 0  eXITO SA (ALMACENES eXITO SA)  ...
# 1               DGERARD MG S.A.S  ...
#
#                                                items     total  \
# 0  Jarra Vidrio Con Tapa en Acero; CAMINO DE MESA...   1358370
# ...
